// %% [markdown]
// ## 1. Imports & backend

// %%
// Adjust the path if you move the minml checkout.
import {  
    m,
    Device,
    DType,
    PRNGKey,
    Dirichlet,
    Categorical,
    Normal,
    vmap,
} from "file:///Users/mauriciobarbadacosta/Downloads/minml/bindings/ts/index.ts";
console.log("imports OK; default device:", m.defaultDevice().value);
// Out:
// imports OK; default device: 0

// %%
// Try GPU first;fall back to CPU/WASM. Switch to { backend: "cpu" } to force WASM.
await m.initWebGPU();

// %% [markdown]
// ## 2. Inspecting Tensors
// Helper that pretty-prints a tensor for the notebook.

// %%
async function inspect(t) {  
    return {    
        shape: t.shape(),    
        dtype: t.dtype() === DType.Int32 ? "int32" : "float32",    
        data: await t.tolist(),  
    };
}
const a = m.array([1, 2, 3, 4], m.Device.WebGPU);
const b = m.array([10, 20, 30, 40], m.Device.WebGPU);
const twos = m.array([2, 2, 2, 2], m.Device.WebGPU);
const c = m.mul(m.add(a, b), twos);
await inspect(c);
// Out:
// { shape: [ 4 ], dtype: "float32", data: [ 22, 44, 66, 88 ] }

// %% [markdown]
// # Simple generative model
// Sampling, distributions, and `vmap`. Move the default device to CPU firstsince the random / sampling primitives are CPU-only today.

// %%
m.setDefaultDevice(m.Device.CPU);

// %%
class Trace {  
    obs;            // (N_obs,) Int32  
    assignments;    // (N_obs,) Int32  
    dists;          // (N_clusters, N_categories) Float32  
    static simulate(key, N_clusters, N_categories, N_obs) {    
        const t = new Trace();    
        const [k1, k2, k3] = key.split(3);    
        t.dists = new Dirichlet(m.ones([N_categories], DType.Float32, Device.CPU))                
            .sample(k1, [N_clusters]);    
        t.assignments = m.randint(k2.k0(), k2.k1(), 0, N_clusters,                              
                                  [N_obs], Device.CPU);    
        const simulateOneObservation = (key, idx) =>      
            new Categorical(m.gather(t.dists, idx)).sample(key, []);    
        t.obs = vmap(simulateOneObservation, [0, 0])(        
            k3.split(N_obs), t.assignments);    
        return t;  
    }
}

// %% [markdown]
// Single trace simulation:

// %%
const trace = Trace.simulate(PRNGKey.new(0), 3, 4, 8);({  dists: await inspect(trace.dists),  assignments: await inspect(trace.assignments),  obs: await inspect(trace.obs),});
// Out:
// {
//   dists: {
//     shape: [ 3, 4 ],
//     dtype: "float32",
//     data: [
//       0.026025988161563873,
//       0.23222918808460236,
//       0.6096919775009155,
//       0.13205288350582123,
//       0.23686616122722626,
//       0.4914940297603607,
//       0.09951993077993393,
//       0.1721198409795761,
//       0.43649742007255554,
//       0.25829777121543884,
//       0.052322421222925186,
//       0.25288236141204834
//     ]
//   },
//   assignments: {
//     shape: [ 8 ],
//     dtype: "int32",
//     data: [
//       2, 0, 0, 2,
//       1, 1, 1, 0
//     ]
//   },
//   obs: {
//     shape: [ 8 ],
//     dtype: "int32",
//     data: [
//       0, 2, 2, 3,
//       1, 1, 0, 2
//     ]
//   }
// }

// %% [markdown]
// vmap'd: produce a batch of traces. Split the root key first so each trace gets its own.

// %%
const N_traces = 5;const root = PRNGKey.new(0);const traceKeys = root.split(N_traces);const traces = vmap(Trace.simulate, [0, null, null, null])(    traceKeys, 3, 4, 10);({  dists: await inspect(traces.dists),  assignments: await inspect(traces.assignments),  obs: await inspect(traces.obs),});
// Out:
// {
//   dists: {
//     shape: [ 5, 3, 4 ],
//     dtype: "float32",
//     data: [
//        0.03578299656510353, 0.01997232809662819,   0.4661552309989929,
//        0.47808942198753357, 0.10690134763717651,   0.2344864308834076,
//        0.29967057704925537, 0.35894161462783813, 0.022099077701568604,
//         0.7258784770965576, 0.05179296061396599,   0.2002294957637787,
//         0.6547591090202332, 0.10178259760141373,  0.16976070404052734,
//        0.07369756698608398,  0.5657760500907898,  0.03907905891537666,
//         0.3266555070877075, 0.06848937273025513,  0.08520522713661194,
//         0.5631458163261414, 0.10421077162027359,   0.2474382221698761,
//         0.6410667896270752, 0.12879157066345215,   0.2184828668832779,
//       0.011658819392323494, 0.04438493028283119,   0.1823054701089859,
//        0.49737972021102905, 0.27592992782592773,  0.03564990311861038,
//         0.1475953608751297, 0.05938933044672012,    0.757365345954895,
// ...
